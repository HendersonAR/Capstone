# %%
import requests
from bs4 import BeautifulSoup

# %%
login_url = 'https://stathead.com/users/login.cgi'
target_url = 'https://stathead.com/fbref/player-season-finder.cgi'
username = 'AndrewRH82'
password = 'LoboBear821$!@$'

# %%
session = requests.Session()

# Get the login page to retrieve any necessary hidden form fields
login_page = session.get(login_url)
soup = BeautifulSoup(login_page.content, 'html.parser')

# Find any hidden form fields (if present)
hidden_inputs = soup.find_all("input", type="hidden")
form_data = {input.get("name"): input.get("value") for input in hidden_inputs}

# Add your username and password to the form data
form_data['username'] = username
form_data['password'] = password

# Submit the login form
response = session.post(login_url, data=form_data)

# Check if login was successful
if "login" not in response.url:
    print("Login successful.")

    # Access the search page after logging in
    search_page = session.get(search_url)
    soup = BeautifulSoup(search_page.content, 'html.parser')

    # Locate the correct form by its ID
    search_form = soup.find("form", {"id": "player-season-finder"})
    if not search_form:
        print("Could not find the search form. Check the form ID.")
    else:
        print("Search form found.")

    # Extract the form action URL
    form_action = search_form.get('action', '')
    if form_action.startswith('/'):
        filter_url = f"https://stathead.com{form_action}"
    else:
        filter_url = f"{search_url}{form_action}"

    print(f"Submitting filters to: {filter_url}")

    # Define the search filters (update with actual filter names)
    filter_data = {
        'year_min': '2018-2019',  # Example: Filter for a specific season
        'year_max': '2018-2019',
        # Add other filters here if needed
    }

    # Include other hidden fields from the search form if required
    hidden_inputs = search_form.find_all("input", type="hidden")
    for input in hidden_inputs:
        filter_data[input.get("name")] = input.get("value")

    # Submit the filter form using POST
    filtered_response = session.post(filter_url, data=filter_data)

    # Check if the response is successful
    if filtered_response.status_code == 200:
        print("Filter form submitted successfully.")
    else:
        print(f"Filter form submission failed with status code: {filtered_response.status_code}")
        print("Trying GET request instead...")
        filtered_response = session.get(filter_url, params=filter_data)

    # Parse the search results page
    filtered_soup = BeautifulSoup(filtered_response.content, 'html.parser')

    # Extract and display data from the results table
    rows = filtered_soup.find_all('tr')
    if not rows:
        print("No data found. Check filter field names.")
    else:
        print("Data retrieved successfully.")
        for row in rows:
            print(row.get_text())

else:
    print("Login failed. Check your credentials.")

# Close the session
session.close()
# Out:
# Login successful.
# Search form found.
# Submitting filters to: https://stathead.com/fbref/player-season-finder.cgi
# Filter form submitted successfully.
# Data retrieved successfully.
#    Playing Time Performance
#  Rk Player Gls Season Age Nation Team Comp MP Min 90s Starts Subs unSub Gls Ast G+A G-PK PK PKatt PKm Pos
# 1Lionel Messi362018-201931ar ARGBarcelonaes La Liga342,71330.1295036134932451FW
# 2Abderrazak Hamdallah342018-201927ma MARAl-Nassrsa Saudi Professional League262,19224.425113494326891FW
# 3Kylian Mbappé332018-201919fr FRAParis S-Gfr Ligue 1292,34326.024503374032121FW
# 4Mbaye Diagne302018-201926sn SEN2 Teamstr Süper Lig292,52228.02810303331812142FW
# 5Teemu Pukki292018-201928fi FINNorwich Cityeng Championship433,81042.343002993829011FW,MF
# 6Simon Terodde292018-201930de GERKölnde 2. Bundesliga332,43827.128512943325451FW
# 7Ferdy Druijf292018-201920nl NED3 Teams2 Comps363,04133.83337291301811121FW
# 8James Norwood292018-201927eng ENGTranmere Roverseng League Two454,04945.045002902928110FW
# 9Robert Skov292018-201922dk DENFC Copenhagendk Danish Superliga342,77930.931302993822781MF
# 10Dušan Tadić282018-201929rs SRBAjaxnl Eredivisie342,90032.234002812401711121FW
# 11Gaëtan Charbonnier272018-201929fr FRABrestfr Ligue 2373,14635.035202783523451FW
# 12Luuk de Jong272018-201927nl NEDPSV Eindhovennl Eredivisie343,06034.034002763327000FW
# 13Danny Rowe272018-201928eng ENGFyldeeng National League454,01044.645012702723440FW,MF
# 14Habib Diallo262018-201923sn SENMetzfr Ligue 2372,68329.82980266321610100FW
# 15Fabio Quagliarella262018-201935it ITASampdoriait Serie A373,19935.5370126834179101FW
# 16Paul McCallum262018-201925eng ENGEastleigheng National League413,37537.538302602624220FW,MF
# 17Neal Maupay252018-201921fr FRABrentfordeng Championship433,70641.243002583322330FW
# 18Alfredo Donnarumma252018-201927it ITABresciait Serie B322,59228.830202573218792FW
# 19James Collins252018-201927ie IRLLuton Towneng League One443,73241.542202532819682FW
# 20Tammy Abraham252018-201920eng ENGAston Villaeng Championship373,13834.937002532820561FW
# 21Mario Engels242018-201924de GERRoda JCnl Eerste Divisie342,97433.034002493318693FW
# 22Nermin Haskić242018-201929ba BIHRadnički Nišrs Serbian SuperLiga342,81831.333102402421330FW
# 23Igor Angulo242018-201934es ESPGórnik Zabrzepl Ekstraklasa373,11234.634302432719550FW
# 24Lawrence Shankland242018-201922sct SCOAyr Unitedsct Scottish Championship312,61829.129202432718660FW
# 25Guillaume Hoarau242018-201934fr FRAYoung Boysch Swiss Super League281,91321.321722473121330FW
# 26Lars Veldwijk242018-201926za RSASparta R'damnl Eerste Divisie362,97733.134212442822220FW
# 27Macauley Bonne232018-201922zw ZIMLeyton Orienteng National League464,13545.946002302317660FW
# 28Stanislav Kostov232018-201926bg BULLevski Sofiabg Bulgarian First League352,58028.731402302322110FW
# 29Haris Seferović232018-201926ch SUIBenficapt Primeira Liga291,96921.920922352823000FW
# 30Nikolay Komlichenko232018-201923ru RUSMladá Boleslavcz Czech First League272,39326.627002352816781FW
# 31Duván Zapata232018-201927co COLAtalantait Serie A372,89632.232502373022121FW
# 32Mbwana Samatta232018-201925tz TANGenkbe Belgian Pro League383,18235.436212352822121FW
# 33Dwight Gayle232018-201927eng ENGWest Bromeng Championship392,83831.533602322523000FW
# 34Billy Sharp232018-201932eng ENGSheffield Utdeng Championship403,01333.534642342722121FW
# 35Marvin Pourié222018-201927de GERKarlsruherde 3. Liga373,15435.037012252722011FW
# 36Krzysztof Piątek222018-201923pl POL2 Teamsit Serie A372,96633.034302202220220FW
# 37Dame N'Doye222018-201933sn SENFC Copenhagendk Danish Superliga332,83431.533002222422000FW
# 38Jay Rodriguez222018-201929eng ENGWest Bromeng Championship453,94343.845002252714891FW
# 39Nicolas Pépé222018-201923ci CIVLillefr Ligue 1383,32436.93710221133139101FW,MF
# 40Tyler Walker222018-201921eng ENGMansfield Towneng League Two443,74041.643102232519330FW
# 41Oliver McBurnie222018-201922sct SCOSwansea Cityeng Championship423,41638.037512242619352FW,MF
# 42Jarrod Bowen222018-201921eng ENGHull Cityeng Championship463,94443.845102242618451MF,FW
# 43Robert Lewandowski222018-201929pl POLBayern Munichde Bundesliga332,95732.933012272919341FW
# 44Andreas Skov Olsen222018-201918dk DENNordsjællanddk Danish Superliga363,05333.933302242619330FW
# 45Sadio Mané222018-201926sn SENLiverpooleng Premier League363,07734.235102212322000FW
# 46Pierre-Emerick Aubameyang222018-201929ga GABArsenaleng Premier League362,72630.330602252718451FW
# 47Mohamed Salah222018-201926eg EGYLiverpooleng Premier League383,25036.137102283019330FW
# 48Che Adams222018-201922sct SCOBirmingham Cityeng Championship463,72841.443302242621110FW
# 49Stephen Dobbie212018-201935sct SCOQueenssct Scottish Championship302,58728.730002132417462FW
# 50Scott Boden212018-201928eng ENG2 Teamseng National League443,62340.341322102116550FW
# 51Tom Eaves212018-201926eng ENGGillinghameng League One433,37337.535802122320143FW
# 52Bafétimbi Gomis212018-201932fr FRA2 Teams2 Comps312,58428.729212172816572FW
# 53Lyle Taylor212018-201928ms MSRCharlton Atheng League One413,63040.3410021829138102FW
# 54Massimo Coda212018-201929it ITABeneventoit Serie B342,92632.533112142515693FW
# 55Sergio Agüero212018-201930ar ARGManchester Cityeng Premier League332,45927.331212182919220FW
# 56André-Pierre Gignac212018-201932fr FRAUANLmx Liga MX282,48927.728002132419220FW
# 57Pedro Manzi212018-201929es ESPChennai Cityin I-League181,48916.518022122317440MF,FW
# 58Huseyin Dogan212018-201924nl NEDOssnl Eerste Divisie363,19135.536002152619242FW
# 59Karim Benzema212018-201930fr FRAReal Madrides La Liga362,95332.835102162718330FW
# 60Willis Plaza212018-201930tt TRIChurchill Brosin I-League201,72819.220002112220110FW,MF
# 61Kamil Wilczek212018-201930pl POLBrøndbydk Danish Superliga332,86131.832102142518341FW
# 62Luis Suárez212018-201931uy URUBarcelonaes La Liga332,82731.431202162717440FW
# 63Léandre Tawamba212018-201928cm CMRAl-Taawounsa Saudi Professional League282,42226.928002152616550FW
# 64Cristiano Ronaldo212018-201933pt PORJuventusit Serie A312,68829.930112182916561FW
# 65John Marquis212018-201926eng ENGDoncastereng League One443,92043.644002142519220FW
# 66Álvaro Giménez202018-201927es ESPAlmeríaes Segunda División393,30836.838102032314671FW
# 67Nicky Maynard202018-201931eng ENGBuryeng League Two372,94232.734302042420000FW
# 68Claudiu Keșerü202018-201931ro ROULudogoretsbg Bulgarian First League352,53628.229602002019110FW
# 69Bruno Fernandes202018-201923pt PORSporting CPpt Primeira Liga332,94032.7330020133314660MF
# 70Ricardo Jorge Pires Gomes202018-201926cv CPVPartizanrs Serbian SuperLiga363,06034.035112012118220FW
# 71Adam Rooney202018-201930ie IRLSalford Cityeng National League382,92432.534422002018220FW,MF
# 72Djaniny202018-201927cv CPVAl-Ahlisa Saudi Professional League211,51116.817402062617330FW
# 73Jayden Stockley202018-201924eng ENG2 Teams2 Comps422,90632.3321032002020011FW
# 74Iago Aspas202018-201930es ESPCelta Vigoes La Liga272,25125.026112062615550FW,MF
# 75Enric Gallego202018-201931es ESP2 Teams2 Comps383,24936.136202022218242FW
# 76Nick Venema202018-201919nl NED2 Teams2 Comps382,32525.82513122032319121FW
# 77Jhon Córdoba202018-201925co COLKölnde 2. Bundesliga311,91121.222922012120000FW
# 78Kieran Agard202018-201928eng ENGMK Donseng League Two433,37037.440322022216473FW
# 79Ian Henderson202018-201933eng ENGRochdaleeng League One453,98444.345012052515550FW,MF
# 80Moanes Dabbur202018-201926il ISRRB Salzburgat Austrian Bundesliga292,13823.823632052519132FW
# 81Mijo Caktaš192018-201926hr CROHajduk Splithr Hrvatska NL282,44227.128001901916341MF
# 82Efthimis Koulouris192018-201922gr GREAtromitosgr Super League Greece282,49727.728001932217231FW,MF
# 83Cristhian Stuani192018-201931uy URUGironaes La Liga322,72930.330201901914550FW
# 84Leonardo Mancuso192018-201926it ITAPescarait Serie B353,00133.334101942315451FW
# 85Adrián Dalmau192018-201924es ESPHeracles Almelonl Eredivisie312,38326.527421932219000FW
# 86Pierre-Yves Hamel192018-201924fr FRALorientfr Ligue 2373,02933.735201932214561FW
# 87Omar Al Somah192018-201929sy SYRAl-Ahlisa Saudi Professional League241,81120.119501962515440FW
# 88Leonardo Rocha192018-201921pt PORLommel SKbe Challenger Pro League322,88032.032001932216341FW
# 89Júnior Moraes192018-201931ua UKRShakhtarua Ukrainian Premier League272,38626.527001972618143FW
# 90Danilo192018-201919br BRA2 Teams2 Comps332,18524.3231041922116341FW
# 91George Țucudean182018-201927ro ROUCFR Clujro Liga I271,93921.524301811918011FW
# 92Ognjen Mudrinski182018-201926rs SRBČukaričkirs Serbian SuperLiga342,30725.628611801817110FW
# 93Jamie Vardy182018-201931eng ENGLeicester Cityeng Premier League342,72630.330401842214451FW
# 94Edinson Cavani182018-201931uy URUParis S-Gfr Ligue 1211,67118.620121852314451FW
# 95Lukas Hinterseer182018-201927at AUTBochumde 2. Bundesliga312,69429.931001852315341FW
# 96Roy Krishna182018-201930fj FIJWellingtonau A-League Men262,20024.425101842214473FW
# 97Mirko Marić182018-201923hr CROOsijekhr Hrvatska NL363,11534.635101801816220FW
# 98Julio Furch182018-201929ar ARGSantosmx Liga MX312,70330.031011862417121FW
# 99Karlan Grant182018-201920eng ENG2 Teams2 Comps413,17235.234711832115341FW
# 100Wissam Ben Yedder182018-201927fr FRASevillaes La Liga352,81231.231421892716220FW
# 101Paco Alcácer182018-201924es ESPDortmundde Bundesliga261,21113.5111521801817110FW
# 102Freddie Ladapo182018-201925eng ENGPlymouth Argyleeng League One453,70241.142301832118000FW
# 103Andrew Wooten182018-201928us USASandhausende 2. Bundesliga312,40026.727401811914440FW
# 104Alfredo Morelos182018-201922co COLRangerssct Scottish Premiership302,20624.527301832118000FW
# 105Marcin Robak182018-201935pl POLŚląsk Wrocławpl Ekstraklasa352,81131.230501832114440FW,MF
# 106Viktor Tsyhankov182018-201920ua UKRDynamo Kyivua Ukrainian Premier League312,64829.4301018102811770MF
# 107Hamdi Harbaoui182018-201933tn TUNZulte Waregembe Belgian Pro League272,36226.227011811914440FW
# 108Kieffer Moore172018-201925wls WALBarnsleyeng League One312,33425.926501732016110FW,MF
# 109Billy Mckay172018-201929nir NIRRoss Countysct Scottish Championship241,82220.222211732013440FW,MF
# 110Vedat Muriqi172018-201924xk KVXRizesportr Süper Lig343,02233.634001782514330FW
# 111Harry Kane172018-201925eng ENGTottenhameng Premier League282,42426.927101742113440FW
# 112Marco Reus172018-201929de GERDortmundde Bundesliga272,31625.727001782514330MF,FW
# 113Luka Jović172018-201920rs SRBEint Frankfurtde Bundesliga322,24324.925721752216110FW,MF
# 114Andrej Kramarić172018-201927hr CROHoffenheimde Bundesliga302,39626.628211742112561MF,FW
# 115Rafa Silva172018-201925pt PORBenficapt Primeira Liga261,91421.321511721917000MF,FW
# 116Florian Ayé172018-201921fr FRAClermont Footfr Ligue 2382,87031.934401742114330FW
# 117Jesús Imaz172018-201927es ESP2 Teamspl Ekstraklasa312,45927.328301732011682MF
# 118Borja Iglesias172018-201925es ESPEspanyoles La Liga373,07534.235201732014330FW
# 119Arkadiusz Milik172018-201924pl POLNapoliit Serie A352,39626.627831732017000FW
# 120Hirving Lozano172018-201923mx MEXPSV Eindhovennl Eredivisie302,45927.330001782513440FW
# 121Raheem Sterling172018-201923eng ENGManchester Cityeng Premier League342,77130.831341792617000FW
# 122Ched Evans172018-201929wls WALFleetwood Towneng League One393,23235.937201732013440FW
# 123Lisandro López172018-201935ar ARGRacing Clubar Liga Profesional Argentina242,08523.224001711811660FW
# 124Paul Onuachu172018-201924ng NGAMidtjyllanddk Danish Superliga302,33525.928201742117000FW
# 125Andrea La Mantia172018-201927it ITALecceit Serie B322,35926.228421752217000FW
# 126Chuks Aneke172018-201925eng ENGMK Donseng League Two382,54728.3261221711815231FW
# 127Wout Weghorst172018-201925nl NEDWolfsburgde Bundesliga342,92532.533101772413440FW
# 128Ben Nabouhane172018-201929km COMRed Starrs Serbian SuperLiga241,86020.72135170178990FW,MF
# 129Fabian Klos172018-201930de GERArminiade 2. Bundesliga332,75530.633001772414330FW
# 130Abdenasser El Khayati172018-201929nl NEDADO Den Haagnl Eredivisie332,92332.5330017122911671MF
# 131Sam Cosgrove172018-201921eng ENGAberdeensct Scottish Premiership352,41426.829621711813451FW
# 132Kai Havertz172018-201919de GERLeverkusende Bundesliga342,89432.233101732014330MF,FW
# 133Mwape Musonda162018-201927zm ZAMBlack Leopardsza Premier Division282,41126.828001601612451FW
# 134Michel Vlap162018-201921nl NEDHeerenveennl Eredivisie342,80331.133101642016000MF,FW
# 135Andrea Petagna162018-201923it ITASPALit Serie A363,03133.735111611710660FW
# 136Carlitos162018-201928es ESPLegia Warsawpl Ekstraklasa362,61129.029701662213330FW
# 137Ivan Santini162018-201929hr CROAnderlechtbe Belgian Pro League342,50927.927731621814220FW
# 138Philipp Klement162018-201925de GERPaderborn 07de 2. Bundesliga312,67029.730101672313341MF
# 139Burak Yılmaz162018-201933tr TUR2 Teamstr Süper Lig221,81320.121101611712451FW
# 140Lewis Grabban162018-201930eng ENGNott'ham Foresteng Championship392,72830.3291001631913374FW
# 141Filip Holender162018-201924hu HUNHonvédhu NB I332,85131.733001601614220FW
# 142Kiros Stanlley Soares Ferraz162018-201929br BRASepahanir Persian Gulf Pro League252,21624.625001631913330FW
# 143Jay O'Shea162018-201929ie IRLBuryeng League Two443,70241.142211642011561MF
# 144Leonardo Ramos162018-201928ar ARGLobos BUAPmx Liga MX231,97121.922101631914220FW
# 145Jonson Clarke-Harris162018-201924jm JAM2 Teamseng League One433,10734.5321101601613341FW
# 146Florian Thauvin162018-201925fr FRAMarseillefr Ligue 1332,61329.030301682414220FW,MF
# 147Robin van Persie162018-201934nl NEDFeyenoordnl Eredivisie251,90421.223221642016000FW,MF
# 148Papiss Cissé162018-201933sn SENAlanyasportr Süper Lig262,23724.925101601616044FW
# 149Franco Jara162018-201930ar ARGPachucamx Liga MX322,64529.431111662211550FW
# 150Tom Boere162018-201925nl NEDTwentenl Eerste Divisie312,12023.62562164208880FW
# 151Timo Werner162018-201922de GERRB Leipzigde Bundesliga302,50927.929101672316011FW
# 152Klaas-Jan Huntelaar162018-201934nl NEDAjaxnl Eredivisie281,33414.8131551642015110FW
# 153Francesco Caputo162018-201930it ITAEmpoliit Serie A383,42038.038001631913363FW
# 154Hakim Ziyech162018-201925ma MARAjaxnl Eredivisie292,40126.7290216132916000FW,MF
# 155Michael Cheek162018-201930eng ENGEbbsfleet Utdeng National League392,26625.2251451601614220FW,MF
# 156Martin Kamburov162018-201937bg BULBeroebg Bulgarian First League342,75230.630411601614220FW
# 157Luciano Pereira Mendes162018-201934br BRAFooladir Persian Gulf Pro League292,57828.629001621813341FW
# 158Davide Lanzafame162018-201931it ITAFerencvároshu NB I282,13523.724421601613330FW,MF
# 159Brian Fernández162018-201923ar ARGNecaxamx Liga MX302,20724.525501652116011MF,FW
# 160Dries Mertens162018-201931be BELNapoliit Serie A352,25225.02312216112715110FW
# 161Thomas Henry162018-201923fr FRA2 Teamsbe Challenger Pro League292,56628.529001621816011FW
# 162Eden Hazard162018-201927be BELChelseaeng Premier League372,92332.5325016153112440FW
# 163Aleksandar Prijović162018-201928rs SRB2 Teams2 Comps241,93521.522201611712451FW
# 164Josh Maja162018-201919ng NGA2 Teams2 Comps311,95621.725651621816000FW
# 165Sam Lammers162018-201921nl NEDHeerenveennl Eredivisie312,69029.930101652111550FW
# 166Quique162018-201928es ESPLa Coruñaes Segunda División362,87331.933311621812440FW
# 167Ezequiel Ponce162018-201921ar ARGAEK Athensgr Super League Greece272,08023.126101642015110FW
# 168Cauley Woodrow162018-201923eng ENGBarnsleyeng League One312,44427.229201621814220FW
# 169Leonardo Pavoletti162018-201929it ITACagliariit Serie A322,73430.431121611716000FW
# 170Manuel Schäffler162018-201929de GERWehende 3. Liga322,52928.129301672314231FW
# 171Ivan Toney162018-201922eng ENGP'borough Utdeng League One443,05433.9311301662216011FW
# 172Anthony van den Hurk162018-201925cw CUW2 Teams2 Comps363,20635.636031601615121FW
# 173Jakov Puljić162018-201924hr CRORijekahr Hrvatska NL291,89821.1191051601614231FW
# 174Adam le Fondre162018-201931eng ENG2 Teams2 Comps282,43727.127111611712451FW
# 175Saleh Al-Shehri162018-201924sa KSAAl-Raedsa Saudi Professional League251,57917.516911621812440FW,MF
# 176Yannick Gomis162018-201926sn SENLensfr Ligue 2383,22235.836201672310660FW,MF
# 177Ishak Belfodil162018-201926dz ALGHoffenheimde Bundesliga281,86320.720851631916000FW,MF
# 178Emmanuel Gigliotti152018-201931ar ARG2 Teams2 Comps292,33626.025401541914121FW
# 179Fyodor Chalov152018-201920ru RUSCSKA Moscowru Russian Premier League302,46327.427301572213220FW
# 180Odsonne Édouard152018-201920fr FRACelticsct Scottish Premiership321,92521.4221001552015000FW
# 181Jack Muldoon152018-201929eng ENGHarrogateeng National League443,20835.640421501513220FW,MF
# 182Jean-Pierre Nsame152018-201925cm CMRYoung Boysch Swiss Super League311,90821.2201141541914132FW
# 183Sargis Adamyan152018-201925am ARMJahn R'burgde 2. Bundesliga332,83831.533001592414110MF,FW
# 184Daniel Kyereh152018-201922gh GHAWehende 3. Liga342,64429.427711531815000FW,MF
# 185Jonathan Okita152018-201922cd CODNEC Nijmegennl Eerste Divisie373,12634.736101572215000FW,MF
# 186Anton Fink152018-201931de GERKarlsruherde 3. Liga382,73330.43350159249671FW
# 187Danilo Moreno Asprilla152018-201929co COLAl-Fayhasa Saudi Professional League282,49927.828001501513220FW,MF
# 188Ciro Immobile152018-201928it ITALazioit Serie A362,85931.831501562111440FW
# 189Ferran Corominas152018-201935es ESPGoain Indian Super League171,49616.617001572212330FW
# 190Joe Pigott152018-201924eng ENGAFC Wimbledoneng League One402,76330.731911541913242FW
# 191Tiquinho Soares152018-201927br BRAPortopt Primeira Liga282,05222.824401531812330FW
# 192Bradley Dack152018-201924eng ENGBlackburneng Championship423,44638.340201572214110MF
# 193Simon Cox152018-201931ie IRLSouthend Unitedeng League One453,66240.742301552013220FW
# 194Radamel Falcao152018-201932co COLMonacofr Ligue 1332,55728.429401521712341FW
# 195Neymar152018-201926br BRAParis S-Gfr Ligue 1171,43916.016101572210550MF,FW
# 196Sean McConville152018-201929eng ENGAcc'ton Stanleyeng League One454,03344.845001572215000MF
# 197Martin Doležal152018-201928cz CZEJabloneccz Czech First League292,45827.328101511615000FW
# 198Danny Graham152018-201932eng ENGBlackburneng Championship433,01433.537631541912330FW
# 199Flávio Paixão152018-201933pt PORLechia Gdańskpl Ekstraklasa373,11834.63520151169693FW,MF
# 200João Félix152018-201918pt PORBenficapt Primeira Liga261,72519.221541572215000FW
